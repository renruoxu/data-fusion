# %%
import caffe

# %% [markdown]
# ###Layer types in Caffe:
# AbsVal, Accuracy, ArgMax, BNLL, Concat, ContrastiveLoss, Convolution, Data, Deconvolution, Dropout, DummyData, Eltwise, EuclideanLoss, Exp, Flatten, HDF5Data, HDF5Output, HingeLoss, Im2col, ImageData, InfogainLoss, InnerProduct, LRN, MVN, MemoryData, MultinomialLogisticLoss, PReLU, Pooling, Power, ReLU, Sigmoid, SigmoidCrossEntropyLoss, Silence, Slice, Softmax, SoftmaxWithLoss, Split, TanH, Threshold, WindowData

# %%
! /home/ruoxu/opt/caffe/build/tools/caffe train --solver=solver.prototxt
# Out:
# I0427 13:36:59.318145 29057 caffe.cpp:117] Use CPU.
# I0427 13:36:59.318652 29057 caffe.cpp:121] Starting Optimization
# I0427 13:36:59.318826 29057 solver.cpp:32] Initializing solver from parameters:
# test_iter: 100
# test_interval: 500
# base_lr: 0.005
# display: 20
# max_iter: 5000
# lr_policy: "inv"
# gamma: 0.0001
# power: 0.75
# momentum: 0.9
# weight_decay: 0.001
# snapshot: 500
# snapshot_prefix: "/home/ruoxu/workspace/x/text-image-caffe/data/snapshots/"
# solver_mode: CPU
# net: "/home/ruoxu/workspace/x/text-image-caffe/train_val.prototxt"
# I0427 13:36:59.319002 29057 solver.cpp:70] Creating training net from net file: /home/ruoxu/workspace/x/text-image-caffe/train_val.prototxt
# I0427 13:36:59.319428 29057 net.cpp:257] The NetState phase (0) differed from the phase (1) specified by a rule in layer data
# I0427 13:36:59.319638 29057 net.cpp:42] Initializing net from parameters:
# name: "Mapping"
# state {
#   phase: TRAIN
# }
# layer {
#   name: "Data"
# ...
